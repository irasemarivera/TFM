# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table
    
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# 3 Unstoppable Stocks That Could Double Your Money in 2021
# Jan-23-21 08:00AM
# 3 Stock Picks for Former President Trump
# 07:00AM
# Dow Jones Futures: Stock Market Rally Riding High; Apple, Microsoft, AMD, Tesla Lead Earnings Tsunami
# 06:51AM
# Will AMC Stock Recover? Don't Bet on It
# 05:57AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Jan-23-21',
#   '08:00AM',
#   '3 Unstoppable Stocks That Could Double Your Money in 2021'],
#  ['AMZN', 'Jan-23-21', '07:00AM', '3 Stock Picks for Former President Trump'],
#  ['AMZN',
#   'Jan-23-21',
#   '06:51AM',
#   'Dow Jones Futures: Stock Market Rally Riding High; Apple, Microsoft, AMD, Tesla Lead Earnings Tsunami'],
#  ['AMZN', 'Jan-23-21', '05:57AM', "Will AMC Stock Recover? Don't Bet on It"],
#  ['AMZN', 'Jan-22-21', '07:35PM', 'Why IBM Stock Plunged Today'],
#  ['AMZN',
#   'Jan-22-21',
#   '05:36PM',
#   'Walmart Says It Is Gearing Up for COVID-19 Vaccine Rollout'],
#  ['AMZN',
#   'Jan-22-21',
#   '05:21PM',
#   'Parlers New Partner Has Ties to the Russian Government'],
#  ['AMZN',
#   'Jan-22-21',
#   '05:06PM',
#   'Short Squeeze Sends GameStop Shares to 2007 Levels. What Happens Next.'],
#  ['AMZN',
#   'Jan-22-21',
#   '03:19PM',
#   'Section 230 Back In Spotlight As Social Media Ban Of Trump Bites Back'],
#  ['AMZN',
#   'Jan-22-21',
#   '03:16PM',
#   'Why BlackBerry Stock Has Almost Doubled in a Week'],
#  ['AMZN',
#   'Jan-22-21',
#   '02:26PM',
#   'GameStop closes up 51% after chaotic day of trading'],
#  ['AMZN',
#   'Jan-22-21',
#   '01:55PM',
#   'Barrons Stock Picks Beat the Market Again Last Year. Heres How We Did It.'],
#  ['AMZN',
#   'Jan-22-21',
#   '12:48PM',
#   'Imitating Amazon, Walmart Tells Government It Can Perform 10 Million to 13 Million Vaccinations Per Month'],
#  ['AMZN',
#   'Jan-22-21',
#   '12:41PM',
#   'Q4 Earnings Season Scorecard and Analyst Reports for Amazon, JPMorgan & Pfizer'],
#  ['AMZN', 'Jan-22-21', '12:37PM', 'Why GameStop Stock Just Popped 21%'],
#  ['AMZN',
#   'Jan-22-21',
#   '12:11PM',
#   'How Elon Musk and Jeff Bezos can help save our democracy'],
#  ['AMZN',
#   'Jan-22-21',
#   '11:55AM',
#   'Lore Leaves Unfinished Business At Walmart'],
#  ['AMZN',
#   'Jan-22-21',
#   '11:49AM',
#   'Samsung Considers $10 Billion Texas Chipmaking Plant, Sources Say'],
#  ['AMZN',
#   'Jan-22-21',
#   '11:49AM',
#   'Dow Jones Falls As IBM, Intel Dive On Earnings; Apple Nears New Buy Point'],
#  ['AMZN',
#   'Jan-22-21',
#   '11:39AM',
#   '2 Strong Buy FAANG Stocks to Watch Heading Into Earnings'],
#  ['AMZN',
#   'Jan-22-21',
#   '11:38AM',
#   'Amazon seeks to halt union election at Alabama warehouse'],
#  ['AMZN',
#   'Jan-22-21',
#   '10:34AM',
#   '200 Million Subscribers Help Power Netflix (NFLX) Higher'],
#  ['AMZN',
#   'Jan-22-21',
#   '10:17AM',
#   'Zacks Value Trader Highlights: Amazon, Facebook, Snap, Twitter and Microsoft'],
#  ['AMZN',
#   'Jan-22-21',
#   '09:58AM',
#   'IBM Shares Tumble After Another Quarterly Revenue Decline'],
#  ['AMZN',
#   'Jan-22-21',
#   '09:42AM',
#   'Intel Tumbles After New CEO Recommits to Chip Manufacturing'],
#  ['AMZN',
#   'Jan-22-21',
#   '09:30AM',
#   'Got $10,000? My 2 Highest Convictions Stocks for 2021 Could Make You a Fortune Over 10 Years'],
#  ['AMZN',
#   'Jan-22-21',
#   '09:17AM',
#   "IBM earnings reveal two major challenges that won't be easily fixed"],
#  ['AMZN',
#   'Jan-22-21',
#   '09:03AM',
#   'Parler dealt major blow in attempt to come back online as judge rules Amazon does not have to restore it'],
#  ['AMZN',
#   'Jan-22-21',
#   '08:38AM',
#   '3 Top Stocks That Will Make You Richer in January and Beyond'],
#  ['AMZN',
#   'Jan-22-21',
#   '08:21AM',
#   'Dow Jones Futures Fall As Stock Market Rally Warnings Grow Louder; Intel Leads Earnings Movers'],
#  ['AMZN',
#   'Jan-22-21',
#   '08:17AM',
#   "If You Own Celsius Holdings Stock, It's Time to Sell"],
#  ['AMZN',
#   'Jan-22-21',
#   '08:15AM',
#   'SPAC Investing: Why Social Capital Picked Clover Health'],
#  ['AMZN',
#   'Jan-22-21',
#   '08:13AM',
#   'IBM Beat Earnings Expectations. Why Its Stock Is Tumbling.'],
#  ['AMZN', 'Jan-22-21', '07:52AM', 'Is Elastic Stock a Buy?'],
#  ['AMZN', 'Jan-22-21', '06:56AM', 'Is CVS Health a Great Dividend Stock?'],
#  ['AMZN',
#   'Jan-22-21',
#   '06:33AM',
#   'Indian trader group says minister pledges strict foreign investment rules for e-commerce'],
#  ['AMZN',
#   'Jan-22-21',
#   '05:51AM',
#   'Got $4,000? 4 Game-Changing Stocks to Buy in 2021'],
#  ['AMZN',
#   'Jan-22-21',
#   '05:15AM',
#   'Amazon to hike fees for Spanish users after new digital tax'],
#  ['AMZN',
#   'Jan-21-21',
#   '10:15PM',
#   'Amazon to open pop-up COVID-19 vaccine clinic in Seattle headquarters'],
#  ['AMZN',
#   'Jan-21-21',
#   '10:12PM',
#   'Amazon to open pop-up COVID-19 vaccine clinic in Seattle headquarters'],
#  ['AMZN',
#   'Jan-21-21',
#   '05:51PM',
#   'Netflix Joins Ranks Of Stocks With 95-Plus Composite Rating'],
#  ['AMZN',
#   'Jan-21-21',
#   '05:45PM',
#   'Amazon (AMZN) Outpaces Stock Market Gains: What You Should Know'],
#  ['AMZN',
#   'Jan-21-21',
#   '05:28PM',
#   "Judge denies Parler's bid to make Amazon restore service"],
#  ['AMZN',
#   'Jan-21-21',
#   '04:56PM',
#   'Dow Jones Futures: Apple, AMD, Nvidia Lead As Stock Market Rally Warning Signs Grow; Intel Leads Earnings Movers Late'],
#  ['AMZN',
#   'Jan-21-21',
#   '04:37PM',
#   'Stock Market Today: Big Tech Keeps the Rally Moving'],
#  ['AMZN',
#   'Jan-21-21',
#   '04:36PM',
#   'Judge Rejects Parlers Bid to Force Amazon to Host Pro-Trump App'],
#  ['AMZN',
#   'Jan-21-21',
#   '04:18PM',
#   "What 'mission-driven' buying means for grocers like Amazon's Whole Foods, Kroger, and more"],
#  ['AMZN',
#   'Jan-21-21',
#   '04:13PM',
#   'Judge wont force Amazon to reinstate Parler'],
#  ['AMZN',
#   'Jan-21-21',
#   '04:12PM',
#   'This Biden tax plan could make Amazon pay taxes but complicate things: expert'],
#  ['AMZN', 'Jan-21-21', '03:15PM', 'Apple (AAPL) Developing Podcast Service'],
#  ['AMZN',
#   'Jan-21-21',
#   '03:06PM',
#   'Parler Judge Refuses to Make Amazon Restore Sites Web Hosting'],
#  ['AMZN',
#   'Jan-21-21',
#   '02:31PM',
#   'YF Premium bullish on Disney as Argus Research raises PT to $200'],
#  ['AMZN',
#   'Jan-21-21',
#   '02:08PM',
#   "Big Tech faces a 'tough' opponent in Merrick Garland as attorney general"],
#  ['AMZN', 'Jan-21-21', '01:36PM', 'Do P/E Ratios Even Matter Anymore?'],
#  ['AMZN',
#   'Jan-21-21',
#   '01:08PM',
#   'Amazon stock price target raised to $4,000 at BofA'],
#  ['AMZN',
#   'Jan-21-21',
#   '01:02PM',
#   'Shopifys Walmart Deal Is Helping Both Retailers. Investors Should Take a Closer Look.'],
#  ['AMZN',
#   'Jan-21-21',
#   '01:01PM',
#   'Rally time? The biggest red flag in this bull market just vanished, trader says'],
#  ['AMZN', 'Jan-21-21', '12:41PM', '2 Big Fintech Stories to Watch'],
#  ['AMZN',
#   'Jan-21-21',
#   '11:40AM',
#   'EBAY vs. AMZN: Which Stock Is the Better Value Option?'],
#  ['AMZN',
#   'Jan-21-21',
#   '10:41AM',
#   "Ahead of AMD's Q4 Earnings: EPYC & Semi-Custom Products in Focus"],
#  ['AMZN',
#   'Jan-21-21',
#   '07:42AM',
#   'United Airlines, Amazon, Intel, FuelCell Energy - 5 Things You Must Know Thursday'],
#  ['AMZN',
#   'Jan-21-21',
#   '07:26AM',
#   '4 Stocks to Watch as Streaming Services Continue to Explode'],
#  ['AMZN',
#   'Jan-21-21',
#   '07:05AM',
#   'Just how generous are Elon Musk and Jeff Bezos?'],
#  ['AMZN', 'Jan-21-21', '07:00AM', 'Influencers with Andy Serwer: Ray McGuire'],
#  ['AMZN',
#   'Jan-21-21',
#   '06:30AM',
#   'Intel Outsourcing Clues Mount Ahead of Earnings Under New CEO'],
#  ['AMZN',
#   'Jan-20-21',
#   '10:27PM',
#   'Amazon Offers To Help Vaccinate 100M Americans In First 100 Days Of Biden Administration'],
#  ['AMZN',
#   'Jan-20-21',
#   '08:19PM',
#   'Indian stock exchanges approve $3.4B Reliance and Future deal in setback for Amazon'],
#  ['AMZN',
#   'Jan-20-21',
#   '07:20PM',
#   'Amazon offers to help Bidens effort to quickly distribute COVID-19 vaccine'],
#  ['AMZN',
#   'Jan-20-21',
#   '06:20PM',
#   'Amazon is offering Biden a hand distributing the Covid vaccine'],
#  ['AMZN',
#   'Jan-20-21',
#   '05:57PM',
#   'How Netflixs overseas expansion fueled its explosive growth in subscribers'],
#  ['AMZN',
#   'Jan-20-21',
#   '05:34PM',
#   'Heres Whats Behind Todays Big Tech-Stock Rally'],
#  ['AMZN',
#   'Jan-20-21',
#   '04:56PM',
#   "Is Kroger Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['AMZN',
#   'Jan-20-21',
#   '04:36PM',
#   'Stock Market Today: Wall Street Welcomes Biden With Resounding Rally'],
#  ['AMZN',
#   'Jan-20-21',
#   '04:28PM',
#   'Dow Jones Rallies As President Biden Sworn In; S&P 500, Nasdaq Hit New Highs; Netflix Breaks Out'],
#  ['AMZN',
#   'Jan-20-21',
#   '04:20PM',
#   'BlackBerry Stock Extends Rally On Facebook Settlement; More Upside From AWS?'],
#  ['AMZN',
#   'Jan-20-21',
#   '03:15PM',
#   'Amazon Offers to Help Biden Administration With Vaccinations'],
#  ['AMZN',
#   'Jan-20-21',
#   '02:42PM',
#   'Indian stock exchanges clear Future-Reliance deal in setback for Amazon'],
#  ['AMZN',
#   'Jan-20-21',
#   '02:40PM',
#   "Netflix's Post-Earnings Surge Might Bode Well for Microsoft, Facebook and Amazon"],
#  ['AMZN',
#   'Jan-20-21',
#   '01:42PM',
#   '15 Biggest Companies That Dont Pay Dividends'],
#  ['AMZN', 'Jan-20-21', '12:50PM', 'How Amazon Makes Money'],
#  ['AMZN',
#   'Jan-20-21',
#   '12:01PM',
#   'Amazon sues EU antitrust regulators for letting Italian case go ahead'],
#  ['AMZN',
#   'Jan-20-21',
#   '11:10AM',
#   'Intel Reports Earnings Tomorrow. Heres What to Expect.'],
#  ['AMZN',
#   'Jan-20-21',
#   '09:19AM',
#   "P&G raises full-fiscal year sales and profit outlooks, 'building on strong momentum' amid COVID-19"],
#  ['AMZN',
#   'Jan-20-21',
#   '08:47AM',
#   "Kohl's (KSS) Up More Than 95% in Three Months: Will Rally Stay?"],
#  ['AMZN',
#   'Jan-20-21',
#   '07:15AM',
#   "Is Amazon Stock A Buy Right Now? Here's What Earnings, Charts Show"],
#  ['AMZN',
#   'Jan-20-21',
#   '07:12AM',
#   '20 Realistic Tech Predictions for 2021 (Part Two)'],
#  ['AMZN',
#   'Jan-20-21',
#   '01:51AM',
#   'Trump Signs Order to Restrict Foreign Use of Cloud Companies'],
#  ['AMZN',
#   'Jan-19-21',
#   '05:41PM',
#   'DataTrek co-Founder on his outlook for the S&P 500'],
#  ['AMZN',
#   'Jan-19-21',
#   '05:07PM',
#   'EBay Explores Strategic Alternatives for Marketplace in Korea'],
#  ['AMZN',
#   'Jan-19-21',
#   '04:33PM',
#   'Netflix adds 8.5 million users in Q4, blowing away estimates'],
#  ['AMZN',
#   'Jan-19-21',
#   '04:30PM',
#   'Sectors to watch as Biden heads to the White House'],
#  ['AMZN',
#   'Jan-19-21',
#   '04:27PM',
#   'One Medical, IBD Stock Of The Day, Breaks Out On Covid Vaccines, Analyst Pick'],
#  ['AMZN',
#   'Jan-19-21',
#   '04:01PM',
#   'Amazon.com to Webcast Fourth Quarter 2020 Financial Results Conference Call'],
#  ['AMZN',
#   'Jan-19-21',
#   '03:45PM',
#   'Parler Reappears With Help From Russian-Owned Service'],
#  ['AMZN',
#   'Jan-19-21',
#   '03:45PM',
#   'Apple stock is not a bubble: Wall Street power player'],
#  ['AMZN', 'Jan-19-21', '01:27PM', '15 Cheapest Online Shopping Sites in USA'],
#  ['AMZN',
#   'Jan-19-21',
#   '12:40PM',
#   'Microsoft bets on GMs Cruise while Amazon and others back Rivian amid electric vehicle boom'],
#  ['AMZN',
#   'Jan-19-21',
#   '11:51AM',
#   'Amazon invests in Quebec to create more than 1,000 new jobs and bring faster delivery to customers with five new facilities'],
#  ['AMZN',
#   'Jan-19-21',
#   '11:18AM',
#   'Amazon Prime member total reaches 142 million in U.S. with more shoppers opting in for a full year, data shows'],
#  ['AMZN', 'Jan-19-21', '11:16AM', 'What to expect from Netflix Q4 earnings'],
#  ['TSLA',
#   'Jan-23-21',
#   '03:03PM',
#   'Dow Jones Futures: Stock Market Rally Extended As Apple, Tesla Lead Earnings Tsunami'],
#  ['TSLA',
#   'Jan-23-21',
#   '01:35PM',
#   'Tesla earnings: Can sales growth match stocks rise?'],
#  ['TSLA',
#   'Jan-23-21',
#   '11:11AM',
#   'SpaceX to Drill for Natural Gas Near Texas Starship Development Site'],
#  ['TSLA',
#   'Jan-23-21',
#   '08:46AM',
#   'Tesla Accuses Employee Who Worked For Company For Less Than 2 Weeks Of Stealing Trade Secrets'],
#  ['TSLA',
#   'Jan-23-21',
#   '06:36AM',
#   "3 Money Mistakes -- And What We've Learned From Them"],
#  ['TSLA',
#   'Jan-22-21',
#   '09:48PM',
#   '28 Barrons Roundtable Picks to Beat the Market'],
#  ['TSLA',
#   'Jan-22-21',
#   '08:23PM',
#   'GM and Ford Stock Finally Capture Some of Teslas Heat. Why This Is Only the Beginning.'],
#  ['TSLA',
#   'Jan-22-21',
#   '08:13PM',
#   'Old Car Brands Emerge in a New Packaging to Compete in a World Fixated on Tesla'],
#  ['TSLA',
#   'Jan-22-21',
#   '05:14PM',
#   "Elon Musk's SpaceX plans natural-gas drilling in Texas: report"],
#  ['TSLA', 'Jan-22-21', '05:03PM', 'EVgo Is Merging With a SPAC to Go Public'],
#  ['TSLA',
#   'Jan-22-21',
#   '04:39PM',
#   "Tesla's too high to buy now; Beyond Meat perking up; GameStop shorts feeling pain: veteran trader"],
#  ['TSLA',
#   'Jan-22-21',
#   '04:20PM',
#   'Stock Market Rally Powers To Highs As Netflix, Apple Lead Big Tech Rally; Tesla Model Y Launches In China: Weekly Review'],
#  ['TSLA',
#   'Jan-22-21',
#   '12:55PM',
#   'Tesla Is Shaking Up One of the Hottest Areas in Solar Power'],
#  ['TSLA',
#   'Jan-22-21',
#   '12:45PM',
#   "Tesla's Musk Offers $100M Reward for Best Carbon-Capture Tech"],
#  ['TSLA',
#   'Jan-22-21',
#   '12:14PM',
#   'Dow Slides As Pelosi Gets Set To Trigger Trump Impeachment; Microsoft Passes Buy Point'],
#  ['TSLA',
#   'Jan-22-21',
#   '12:11PM',
#   'How Elon Musk and Jeff Bezos can help save our democracy'],
#  ['TSLA', 'Jan-22-21', '12:03PM', 'Why NIO Stock Is Up Today'],
#  ['TSLA',
#   'Jan-22-21',
#   '11:52AM',
#   'This Study Shows Tesla Leading The Charge In Online Car Sales'],
#  ['TSLA',
#   'Jan-22-21',
#   '11:49AM',
#   'Samsung Considers $10 Billion Texas Chipmaking Plant, Sources Say'],
#  ['TSLA',
#   'Jan-22-21',
#   '11:49AM',
#   'Dow Jones Falls As IBM, Intel Dive On Earnings; Apple Nears New Buy Point'],
#  ['TSLA', 'Jan-22-21', '11:12AM', '2020 Was a Rough Year for Short Sellers'],
#  ['TSLA', 'Jan-22-21', '10:56AM', 'Weekend reads: Buy GM and sell Tesla'],
#  ['TSLA',
#   'Jan-22-21',
#   '10:00AM',
#   'Nano One Materials Is a Rare, Truly Innovative Company'],
#  ['TSLA',
#   'Jan-22-21',
#   '09:33AM',
#   'EVgo Charging Network Reportedly Close to Merger With SPAC'],
#  ['TSLA',
#   'Jan-22-21',
#   '08:20AM',
#   'PACCAR (PCAR) Gears Up for Q4 Earnings: Factors at Play'],
#  ['TSLA',
#   'Jan-22-21',
#   '08:17AM',
#   'Is a Beat Likely for Tesla (TSLA) This Earnings Season?'],
#  ['TSLA',
#   'Jan-22-21',
#   '08:08AM',
#   'If youre expecting traditional value stocks to outperform growth stocks, you are going to wait forever, this fund manager says'],
#  ['TSLA', 'Jan-22-21', '07:05AM', 'Better Buy: Tesla vs. General Motors'],
#  ['TSLA', 'Jan-22-21', '06:30AM', 'Buy XPeng Stock Because AV Is the New EV'],
#  ['TSLA',
#   'Jan-22-21',
#   '04:59AM',
#   "Tesla Secures Top Spot In JD Power's Survey Of Premium EV Owners"],
#  ['TSLA',
#   'Jan-22-21',
#   '04:59AM',
#   'Long road for Tesla in India with infrastructure, supply chain woes'],
#  ['TSLA',
#   'Jan-22-21',
#   '04:54AM',
#   'Long road for Tesla in India with infrastructure, supply chain woes'],
#  ['TSLA',
#   'Jan-21-21',
#   '09:14PM',
#   'EV Startup Aiways Said to Seek Funds at $2 Billion Value'],
#  ['TSLA',
#   'Jan-21-21',
#   '09:10PM',
#   "Elon Musk To Award $100M For Development Of 'Best' Carbon Capture Tech"],
#  ['TSLA',
#   'Jan-21-21',
#   '07:37PM',
#   "Elon Musk to offer $100 million prize for 'best' carbon capture tech"],
#  ['TSLA',
#   'Jan-21-21',
#   '07:35PM',
#   "Elon Musk to offer $100 mln prize for 'best' carbon capture tech"],
#  ['TSLA',
#   'Jan-21-21',
#   '05:28PM',
#   'Tesla Takes Charge: Battery Manufacturing Shown Close To Fully Automated In Teaser Video'],
#  ['TSLA',
#   'Jan-21-21',
#   '04:54PM',
#   'From brain drain to brain gain: Miami mayors plan to turn the city into a tech hub'],
#  ['TSLA',
#   'Jan-21-21',
#   '04:17PM',
#   'Tesla bears suffer record short-sale loss in 2020 -S3 Partners'],
#  ['TSLA',
#   'Jan-21-21',
#   '03:22PM',
#   'The Bull Case for FuboTV and More on the Market From David Einhorns Greenlight Capital'],
#  ['TSLA',
#   'Jan-21-21',
#   '01:40PM',
#   'Dow Jones Rallies As Biden Issues Covid-19 Orders; Apple Stock Rises'],
#  ['TSLA',
#   'Jan-21-21',
#   '12:58PM',
#   'Greenlight Calls Owning Tesla Stock a Fad Amid Silly Surge'],
#  ['TSLA',
#   'Jan-21-21',
#   '12:20PM',
#   'David Einhorn  Notorious Tesla Short Seller  Just Had His Best Quarter Ever'],
#  ['TSLA',
#   'Jan-21-21',
#   '11:55AM',
#   'Dow Jones Hits Record High As Apple Jumps; Hot IPO Stock Airbnb Triggers Key Sell Rule'],
#  ['TSLA',
#   'Jan-21-21',
#   '11:32AM',
#   'Volkswagen CEO Joins Twitter to Take on Teslas Elon Musk'],
#  ['TSLA',
#   'Jan-21-21',
#   '10:31AM',
#   "Tesla watch out: Ford & GM's stock prices are exploding"],
#  ['TSLA', 'Jan-21-21', '09:45AM', 'Ford (F) Enters First Uptrend Since 2013'],
#  ['TSLA',
#   'Jan-21-21',
#   '09:14AM',
#   "Tesla isn't the only auto stock exploding right now"],
#  ['TSLA',
#   'Jan-21-21',
#   '07:52AM',
#   'Why Tesla Will Find Indian Auto Market A Tough Nut To Crack'],
#  ['TSLA',
#   'Jan-21-21',
#   '07:41AM',
#   'Battery breakthrough could make charging cars as quick as filling up with fuel'],
#  ['TSLA',
#   'Jan-21-21',
#   '07:25AM',
#   '5 Domestic Auto Stocks to Strengthen Your Portfolio'],
#  ['TSLA',
#   'Jan-21-21',
#   '07:05AM',
#   'Just how generous are Elon Musk and Jeff Bezos?'],
#  ['TSLA', 'Jan-21-21', '07:00AM', 'Influencers with Andy Serwer: Ray McGuire'],
#  ['TSLA',
#   'Jan-21-21',
#   '06:26AM',
#   'The Zacks Analyst Blog Highlights: Tesla, FedEx, General Motors, Deere & Co and Lennar'],
#  ['TSLA',
#   'Jan-21-21',
#   '06:00AM',
#   "Volkswagen CEO To Now Compete With Elon Musk On Twitter, Warns Of Grabbing 'Some Market Share' From Tesla"],
#  ['TSLA',
#   'Jan-21-21',
#   '06:00AM',
#   'Teslas Earnings Report Is Coming. How to Play It With Options.'],
#  ['TSLA',
#   'Jan-21-21',
#   '05:52AM',
#   'Tesla Model 3 Explodes In Shanghai Parking Lot: Report'],
#  ['TSLA',
#   'Jan-21-21',
#   '04:55AM',
#   'Teslas California Registrations Surge 63% in 4Q  Report'],
#  ['TSLA',
#   'Jan-21-21',
#   '01:47AM',
#   'Panasonic Has Been a Tesla Play and Vaccine Bet. Now the Stocks\xa0Rising\xa0on Cold Storage.'],
#  ['TSLA',
#   'Jan-20-21',
#   '09:06PM',
#   'Tesla Sees 63% Rise In California Registrations, Thanks To Model Y'],
#  ['TSLA',
#   'Jan-20-21',
#   '08:00PM',
#   'Tesla fourth-quarter registrations in California jump 63% - data'],
#  ['TSLA',
#   'Jan-20-21',
#   '06:58PM',
#   'Tesla Could Surpass the 1 Million Delivery Mark by 2022, Says Analyst'],
#  ['TSLA',
#   'Jan-20-21',
#   '05:45PM',
#   'Tesla (TSLA) Gains But Lags Market: What You Should Know'],
#  ['TSLA',
#   'Jan-20-21',
#   '04:18PM',
#   'Tesla Cuts Prices On European Model 3: Report'],
#  ['TSLA',
#   'Jan-20-21',
#   '04:04PM',
#   'Why This ATV, Motorcycle Maker Is An Overlooked Electric Vehicle Stock: Analyst'],
#  ['TSLA',
#   'Jan-20-21',
#   '04:03PM',
#   'Tesla Stock Forecasts Keep Hitting Highs As Wall Street Struggles To See Ceiling'],
#  ['TSLA',
#   'Jan-20-21',
#   '03:41PM',
#   'Mercedes-Benz Unveils Entry-Level EQA Electric SUV: What You Need to Know'],
#  ['TSLA',
#   'Jan-20-21',
#   '03:25PM',
#   'Top Consumer Discretionary Stocks for February 2021'],
#  ['TSLA',
#   'Jan-20-21',
#   '02:51PM',
#   '5 reasons why 2021 just might be the year GMs stock price stands up to Tesla'],
#  ['TSLA',
#   'Jan-20-21',
#   '02:38PM',
#   "Mobileye CEO Says Tesla's Self Driving Effort Likely To Hit 'Glass Ceiling'"],
#  ['TSLA',
#   'Jan-20-21',
#   '12:43PM',
#   'Dow Jones Rallies As Biden Is Sworn In; Netflix Stock Passes Buy, Apple Stock Rises'],
#  ['TSLA',
#   'Jan-20-21',
#   '12:38PM',
#   'Wall Street is in its riskiest mindset in 20 years: BofA survey'],
#  ['TSLA',
#   'Jan-20-21',
#   '11:51AM',
#   'Dow Jones Jumps 225 Points As Biden Prepares To Become President; Netflix Soars 15% On Earnings'],
#  ['TSLA',
#   'Jan-20-21',
#   '11:48AM',
#   "Nio's William Li: Tesla's Price-Cutting Strategy May Not Work For Chinese Automaker"],
#  ['TSLA',
#   'Jan-20-21',
#   '11:14AM',
#   'VW CEO Talks a Little Trash With Teslas Musk in Twitter Debut'],
#  ['TSLA',
#   'Jan-20-21',
#   '10:58AM',
#   'Tesla analyst more than doubles stock price target to $1,036'],
#  ['TSLA',
#   'Jan-20-21',
#   '10:43AM',
#   'Is Nio Stock A Buy As China EV Leader Surges After Unveiling Luxury Sedan?'],
#  ['TSLA', 'Jan-20-21', '10:11AM', 'Stock Market News for Jan 20, 2021'],
#  ['TSLA',
#   'Jan-20-21',
#   '08:53AM',
#   'Tesla Just Got a Price Bump Worth Two Toyotas. What a Dozen Analysts Says About the Stock in 2021.'],
#  ['TSLA',
#   'Jan-20-21',
#   '08:25AM',
#   "If You Bought Tesla Stock Instead Of A Model S At Launch, Here's How Much You'd Have Now"],
#  ['TSLA',
#   'Jan-20-21',
#   '08:00AM',
#   '9 Top Nasdaq Stocks Are Already Beating The Market By 15X'],
#  ['TSLA',
#   'Jan-20-21',
#   '07:54AM',
#   'Tesla stock rises as price target tops $1,000 at Oppenheimer'],
#  ['TSLA',
#   'Jan-20-21',
#   '07:52AM',
#   'Top 5 Growth Picks on Expectations of Higher Fiscal Stimulus'],
#  ['TSLA',
#   'Jan-20-21',
#   '07:50AM',
#   'Tesla Shares Jump As Oppenheimer Boosts Price Target to Wall Street High $1,036'],
#  ['TSLA',
#   'Jan-20-21',
#   '07:06AM',
#   "Ex-Google engineer granted full pardon backed by Trump's major tech ally, Peter Thiel"],
#  ['TSLA',
#   'Jan-20-21',
#   '07:05AM',
#   'Why Tesla is not a safe\xa0stock for long-term investors'],
#  ['TSLA',
#   'Jan-20-21',
#   '06:15AM',
#   'Mercedes unveils electric compact SUV in bid to outdo Tesla'],
#  ['TSLA',
#   'Jan-20-21',
#   '06:00AM',
#   'RPT-COLUMN-Macro zen quietens stock bubble clamour: Mike Dolan'],
#  ['TSLA',
#   'Jan-20-21',
#   '05:01AM',
#   "Elon Musk's 'Not A Flamethrower' Gets Buyers In Trouble With Law Across The Globe: TechCrunch"],
#  ['TSLA',
#   'Jan-20-21',
#   '02:50AM',
#   "Tesla Seeks A 'Specialist' To Address 'Social Media Escalations' Aimed At CEO Elon Musk"],
#  ['TSLA',
#   'Jan-20-21',
#   '02:00AM',
#   'COLUMN-Macro zen quietens stock bubble clamour: Mike Dolan'],
#  ['TSLA',
#   'Jan-20-21',
#   '12:02AM',
#   'Tesla Faces Bumpy Ride Breaking Into India Market'],
#  ['TSLA',
#   'Jan-19-21',
#   '09:44PM',
#   'Tesla, Bitcoin More Likely To Halve Than Double Value In 2021: Deutsche Bank Survey'],
#  ['TSLA',
#   'Jan-19-21',
#   '06:20PM',
#   "Elon Musk said it was 'Not a Flamethrower'"],
#  ['TSLA',
#   'Jan-19-21',
#   '05:41PM',
#   'DataTrek co-Founder on his outlook for the S&P 500'],
#  ['TSLA',
#   'Jan-19-21',
#   '04:23PM',
#   'Tesla Delivers First Made-In-China Model Y But VW Eyes Price War'],
#  ['TSLA',
#   'Jan-19-21',
#   '04:14PM',
#   'GM Stock Hits Post-Bailout High After Gaining Big Self-Driving Ally'],
#  ['TSLA',
#   'Jan-19-21',
#   '04:00PM',
#   'Chinas Tech Giants Are Muscling In on Lucrative IPO Market'],
#  ['TSLA',
#   'Jan-19-21',
#   '03:52PM',
#   'Microsoft and GMs Cruise partnering on self-driving cars'],
#  ['TSLA',
#   'Jan-19-21',
#   '03:45PM',
#   'Apple stock is not a bubble: Wall Street power player'],
#  ['GOOG',
#   'Jan-23-21',
#   '10:05AM',
#   '3 Ways to Invest in Connected-TV Advertising'],
#  ['GOOG',
#   'Jan-23-21',
#   '06:51AM',
#   'Dow Jones Futures: Stock Market Rally Riding High; Apple, Microsoft, AMD, Tesla Lead Earnings Tsunami'],
#  ['GOOG',
#   'Jan-23-21',
#   '05:51AM',
#   "4 Robinhood Growth Stocks That'll Make You Richer in 2021"],
#  ['GOOG', 'Jan-22-21', '06:22PM', 'Daily Crunch: Alphabet shuts down Loon'],
#  ['GOOG',
#   'Jan-22-21',
#   '04:06PM',
#   'Tech Bulls Look to Upcoming Earnings to Remedy FANG Fatigue'],
#  ['GOOG',
#   'Jan-22-21',
#   '03:19PM',
#   'Section 230 Back In Spotlight As Social Media Ban Of Trump Bites Back'],
#  ['GOOG',
#   'Jan-22-21',
#   '02:41PM',
#   'Google and Australias fight is one that could decide the future of the internet'],
#  ['GOOG',
#   'Jan-22-21',
#   '02:01PM',
#   'Stock Market Today With Jim Cramer: IBM and Intel Disappoint'],
#  ['GOOG', 'Jan-22-21', '01:31PM', '15 Biggest VR Companies in the World'],
#  ['GOOG',
#   'Jan-22-21',
#   '01:06PM',
#   'Google Says New Law Would Be the End of Search Services In Australia'],
#  ['GOOG',
#   'Jan-22-21',
#   '12:58PM',
#   'Trump is out of office and off Twitter, but that wont stop disinformation from spreading online'],
#  ['GOOG',
#   'Jan-22-21',
#   '12:41PM',
#   'Alphabet Shuts Down a Much-Hyped Moon Shot'],
#  ['GOOG',
#   'Jan-22-21',
#   '12:22PM',
#   'Dating App Bumble Warns in IPO Filing New Privacy Measures Could Hit Revenue'],
#  ['GOOG',
#   'Jan-22-21',
#   '11:49AM',
#   'Samsung Considers $10 Billion Texas Chipmaking Plant, Sources Say'],
#  ['GOOG',
#   'Jan-22-21',
#   '11:47AM',
#   'EU lawmakers want Amazon, Apple, Facebook, Google CEOs at Feb. 1 hearing'],
#  ['GOOG',
#   'Jan-22-21',
#   '11:40AM',
#   'EU lawmakers want Amazon, Apple, Facebook, Google CEOs at Feb. 1 hearing'],
#  ['GOOG',
#   'Jan-22-21',
#   '11:19AM',
#   'Googles ambitious Loon internet balloon project has crash-landed'],
#  ['GOOG',
#   'Jan-22-21',
#   '10:15AM',
#   'Is Google Stock A Buy As Online Advertising Rebounds Amid More Cloud Transparency?'],
#  ['GOOG',
#   'Jan-22-21',
#   '10:03AM',
#   'The Zacks Analyst Blog Highlights: Alibaba, Procter & Gamble, Wells Fargo, Google and NextEra Energy'],
#  ['GOOG',
#   'Jan-22-21',
#   '09:51AM',
#   "Facebook (FB) to Report Q4 Earnings: What's in the Cards?"],
#  ['GOOG',
#   'Jan-22-21',
#   '09:46AM',
#   'Google threatens to close its search engine in Australia as it lobbies against digital news code'],
#  ['GOOG',
#   'Jan-22-21',
#   '09:22AM',
#   'Developer complains to EU over Apple, Google app rules after COVID game rejected'],
#  ['GOOG',
#   'Jan-22-21',
#   '08:58AM',
#   'Loon: Googles balloon-based internet project has finally been shut down'],
#  ['GOOG',
#   'Jan-22-21',
#   '08:32AM',
#   'Virtual reality will be a trillion-dollar marketplace within five years  heres a good example why'],
#  ['GOOG',
#   'Jan-22-21',
#   '08:08AM',
#   'If youre expecting traditional value stocks to outperform growth stocks, you are going to wait forever, this fund manager says'],
#  ['GOOG',
#   'Jan-22-21',
#   '07:59AM',
#   '3 Stocks to Gain From an Uptick in Demand for Cloud Gaming'],
#  ['GOOG',
#   'Jan-22-21',
#   '07:58AM',
#   "Intel, Google, IBM, Biden's Covid Plan - 5 Things You Must Know Friday"],
#  ['GOOG',
#   'Jan-22-21',
#   '06:32AM',
#   'Google Threatens to Shut Off Australia Over Media Protection Law'],
#  ['GOOG',
#   'Jan-22-21',
#   '06:01AM',
#   'Alphabet Pops Air Out Of Internet Balloon Project'],
#  ['GOOG',
#   'Jan-22-21',
#   '05:45AM',
#   'The Zacks Analyst Blog Highlights: CEVA, KB Home, WilliamsSonoma, Facebook and Alphabet'],
#  ['GOOG',
#   'Jan-22-21',
#   '05:19AM',
#   'Alphabet shutting Loon, which used balloon alternative to cell towers'],
#  ['GOOG',
#   'Jan-22-21',
#   '04:01AM',
#   "Privacy complaint targets European parliament's COVID-19 test-booking site"],
#  ['GOOG',
#   'Jan-22-21',
#   '01:48AM',
#   'Apple VR Headset To Arrive In 2022 And At A Steep Price: Report'],
#  ['GOOG',
#   'Jan-22-21',
#   '12:40AM',
#   'Google says goodbye to giant internet balloons idea'],
#  ['GOOG',
#   'Jan-22-21',
#   '12:29AM',
#   'Google Threatens to Remove Search as Australian Row Deepens'],
#  ['GOOG',
#   'Jan-21-21',
#   '11:21PM',
#   'Google threatens to pull its search engine from Australia'],
#  ['GOOG',
#   'Jan-21-21',
#   '11:00PM',
#   "Australian local govt PR website given 'news' status by Google, Facebook"],
#  ['GOOG',
#   'Jan-21-21',
#   '10:45PM',
#   'Australian local govt PR website given "news" status by Google, Facebook'],
#  ['GOOG',
#   'Jan-21-21',
#   '10:22PM',
#   'Why Google Is Threatening To Deprive Australians Of Its Search Engine'],
#  ['GOOG',
#   'Jan-21-21',
#   '09:44PM',
#   'Alphabet shutting down Loon, its project to beam internet from balloons'],
#  ['GOOG',
#   'Jan-21-21',
#   '08:40PM',
#   'Alphabet Shuts\xa0Loon Project to Beam Internet From High-Altitude Balloons'],
#  ['GOOG',
#   'Jan-21-21',
#   '08:14PM',
#   'Google says to block search engine in Australia if forced to pay for news'],
#  ['GOOG',
#   'Jan-21-21',
#   '08:12PM',
#   'Google says it will remove search function in Australia if media code becomes law'],
#  ['GOOG',
#   'Jan-21-21',
#   '07:54PM',
#   'Alphabet shutting down Loon, which used balloon alternative to cell towers'],
#  ['GOOG',
#   'Jan-21-21',
#   '07:42PM',
#   'Alphabet shuts down Loon internet balloon company'],
#  ['GOOG',
#   'Jan-21-21',
#   '05:45PM',
#   'Alphabet (GOOGL) Outpaces Stock Market Gains: What You Should Know'],
#  ['GOOG',
#   'Jan-21-21',
#   '04:54PM',
#   'From brain drain to brain gain: Miami mayors plan to turn the city into a tech hub'],
#  ['GOOG',
#   'Jan-21-21',
#   '04:52PM',
#   'Bitcoin Losses Gather Pace, With Prices Nearing Three-Week Low'],
#  ['GOOG',
#   'Jan-21-21',
#   '02:08PM',
#   "Big Tech faces a 'tough' opponent in Merrick Garland as attorney general"],
#  ['GOOG',
#   'Jan-21-21',
#   '01:21PM',
#   'Google judge says U.S. states must begin turning over documents next month'],
#  ['GOOG',
#   'Jan-21-21',
#   '01:08PM',
#   'Amazon stock price target raised to $4,000 at BofA'],
#  ['GOOG',
#   'Jan-21-21',
#   '01:01PM',
#   'Rally time? The biggest red flag in this bull market just vanished, trader says'],
#  ['GOOG',
#   'Jan-21-21',
#   '11:56AM',
#   'AI-powered transcription service Otter.ai can now record from Google Meet'],
#  ['GOOG',
#   'Jan-21-21',
#   '11:31AM',
#   'Google inks deal with French publishers on copyright payments for online news'],
#  ['GOOG',
#   'Jan-21-21',
#   '11:30AM',
#   'Has Alphabet (GOOGL) Outpaced Other Computer and Technology Stocks This Year?'],
#  ['GOOG',
#   'Jan-21-21',
#   '09:54AM',
#   'Wimkin: Google joins Apple in banning app described as the next Parler'],
#  ['GOOG',
#   'Jan-21-21',
#   '08:13AM',
#   'Dow Jones Futures Signal Fresh Record Highs, But Stock Market Rally Flashes This Warning; Netflix Leads Six Breakouts'],
#  ['GOOG',
#   'Jan-21-21',
#   '07:18AM',
#   'Google inks agreement in France on paying publishers for news reuse'],
#  ['GOOG',
#   'Jan-21-21',
#   '06:30AM',
#   'Intel Outsourcing Clues Mount Ahead of Earnings Under New CEO'],
#  ['GOOG',
#   'Jan-21-21',
#   '06:00AM',
#   'Apples First Headset\xa0to Be Niche Precursor to Eventual AR Glasses'],
#  ['GOOG',
#   'Jan-21-21',
#   '04:09AM',
#   'Google Signs Deal With French Media to Pay for Content'],
#  ['GOOG',
#   'Jan-21-21',
#   '03:03AM',
#   'Twitter Locks Out Chinese Embassy in U.S. Over Post on Uighurs'],
#  ['GOOG',
#   'Jan-20-21',
#   '10:38PM',
#   "Netflix To Rollout 'Shuffle Play' Feature Around The World In Coming Months"],
#  ['GOOG',
#   'Jan-20-21',
#   '08:59PM',
#   'Google Sidelines Second Artificial Intelligence Researcher'],
#  ['GOOG',
#   'Jan-20-21',
#   '05:34PM',
#   'Heres Whats Behind Todays Big Tech-Stock Rally'],
#  ['GOOG',
#   'Jan-20-21',
#   '05:12PM',
#   'Dow Jones Futures: Stock Market Rally Hits Record Highs, But This Risk Returns; Netflix, Google Lead Six Breakouts'],
#  ['GOOG',
#   'Jan-20-21',
#   '03:32PM',
#   'How we can save the internet without destroying Section 230'],
#  ['GOOG',
#   'Jan-20-21',
#   '03:13PM',
#   'Dow Jones Up After Joe Biden Inauguration; Nasdaq, S&P 500 Hit New Highs; Netflix Flashes Buy Signal'],
#  ['GOOG',
#   'Jan-20-21',
#   '01:42PM',
#   '15 Biggest Companies That Dont Pay Dividends'],
#  ['GOOG',
#   'Jan-20-21',
#   '01:35PM',
#   'Dow Jones Rallies 250 Points, Helped By Bullish Moves From Apple, Microsoft; 2 FANG Stocks Give Buy Signals'],
#  ['GOOG',
#   'Jan-20-21',
#   '12:53PM',
#   'Former Google Engineer Anthony Levandowski Pardoned by Trump'],
#  ['GOOG', 'Jan-20-21', '12:50PM', 'How Amazon Makes Money'],
#  ['GOOG',
#   'Jan-20-21',
#   '10:58AM',
#   "Google asks U.S. judge to move states' antitrust lawsuit to California"],
#  ['GOOG',
#   'Jan-20-21',
#   '10:43AM',
#   "Google's advertising practices targeted by EU antitrust probe"],
#  ['GOOG',
#   'Jan-20-21',
#   '10:16AM',
#   'Google and Fitbit said I do, but the marriage could still be annulled'],
#  ['GOOG',
#   'Jan-20-21',
#   '10:09AM',
#   'Facebook (FB) Faces Mounting Heat Over Media Market Monopoly'],
#  ['GOOG',
#   'Jan-20-21',
#   '08:33AM',
#   'Dow Jones Futures: Netflix Flashes Buy Signal, Alibaba Jumps On Jack Ma; Nasdaq Set To Hit High In Stock Market Rally'],
#  ['GOOG',
#   'Jan-20-21',
#   '07:13AM',
#   'Trump pardons Google engineer who wanted to start a religion worshipping AI'],
#  ['GOOG',
#   'Jan-20-21',
#   '07:06AM',
#   "Ex-Google engineer granted full pardon backed by Trump's major tech ally, Peter Thiel"],
#  ['GOOG',
#   'Jan-20-21',
#   '06:43AM',
#   'Dow Jones Futures: Netflix Flashes Buy Signal; Stock Market Rally Fuels Qualcomm, IPO Breakouts'],
#  ['GOOG',
#   'Jan-20-21',
#   '06:02AM',
#   'The Zacks Analyst Blog Highlights: Alphabet, Facebook, Microsoft, Apple and Snap'],
#  ['GOOG',
#   'Jan-20-21',
#   '02:29AM',
#   'Former Google Self-Driving Engineer Levandowski Gets Trump Pardon In Last Night Clemency Spree'],
#  ['GOOG',
#   'Jan-20-21',
#   '02:20AM',
#   'Former Google engineer Anthony Levandowski among list of last-minute Trump pardons'],
#  ['GOOG',
#   'Jan-20-21',
#   '01:59AM',
#   'Trump Pardons Levandowski, Who Stole Trade Secrets From Google'],
#  ['GOOG',
#   'Jan-20-21',
#   '01:05AM',
#   'Trump pardons former Google engineer Anthony Levandowski'],
#  ['GOOG',
#   'Jan-19-21',
#   '06:46PM',
#   'GameStop Stock Is Soaring. It Could End Badly.'],
#  ['GOOG',
#   'Jan-19-21',
#   '06:24PM',
#   'YouTube Extends Trump Suspension Ahead of Bidens Inauguration'],
#  ['GOOG',
#   'Jan-19-21',
#   '04:53PM',
#   'Dow Jones Futures: Stock Market Rally Fuels Qualcomm, IPO Breakouts; Netflix Flashes Buy Signal Late'],
#  ['GOOG',
#   'Jan-19-21',
#   '04:26PM',
#   'Aurora Gets Autonomous-Truck Validation in Paccar Deal'],
#  ['GOOG',
#   'Jan-19-21',
#   '03:45PM',
#   'Uganda has blocked social media indefinitely as diplomatic tensions spike with US'],
#  ['GOOG',
#   'Jan-19-21',
#   '03:45PM',
#   'Parler Reappears With Help From Russian-Owned Service'],
#  ['GOOG',
#   'Jan-19-21',
#   '03:45PM',
#   'Apple stock is not a bubble: Wall Street power player'],
#  ['GOOG',
#   'Jan-19-21',
#   '12:40PM',
#   'Microsoft bets on GMs Cruise while Amazon and others back Rivian amid electric vehicle boom'],
#  ['GOOG',
#   'Jan-19-21',
#   '12:08PM',
#   'Facebooks WhatsApp Asked to Withdraw Privacy Policy By India  Report'],
#  ['GOOG',
#   'Jan-19-21',
#   '10:32AM',
#   'Biden administration means more regulatory uncertainty for big tech'],
#  ['GOOG',
#   'Jan-19-21',
#   '10:25AM',
#   'Are the FAANG Stocks About to Break Out Again?'],
#  ['GOOG',
#   'Jan-19-21',
#   '09:01AM',
#   '4 Tech Stocks to Buy as Augmented Reality Boom Continues'],
#  ['GOOG',
#   'Jan-19-21',
#   '08:00AM',
#   'Netflixs Earnings Report Will Be a Blockbuster. How to Play It With Options.'],
#  ['GOOG',
#   'Jan-19-21',
#   '06:45AM',
#   "How Democrats could end Wall Street's infatuation with Facebook, Amazon and Google"],
#  ['GOOG',
#   'Jan-19-21',
#   '04:57AM',
#   "Google backs India's Dunzo in $40 million funding round"]]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2021-01-23  08:00AM
# 1   AMZN  2021-01-23  07:00AM
# 2   AMZN  2021-01-23  06:51AM
# 3   AMZN  2021-01-23  05:57AM
# 4   AMZN  2021-01-22  07:35PM
#
#                                             headline    neg    neu  pos  \
# 0  3 Unstoppable Stocks That Could Double Your Mo...  0.184  0.816  0.0
# 1           3 Stock Picks for Former President Trump  0.000  1.000  0.0
# 2  Dow Jones Futures: Stock Market Rally Riding H...  0.000  1.000  0.0
# 3            Will AMC Stock Recover? Don't Bet on It  0.000  1.000  0.0
# 4                        Why IBM Stock Plunged Today  0.000  1.000  0.0
#
#    compound
# 0   -0.2023
# 1    0.0000
# 2    0.0000
# 3    0.0000
# 4    0.0000

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
